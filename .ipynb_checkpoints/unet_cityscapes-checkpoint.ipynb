# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["axes.grid"] = False # to disable grid output
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import cv2
from os.path import join
import os
import random
from functools import partial

# %%
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Reshape, concatenate, Activation, Dropout, MaxPool2D, merge
from keras.optimizers import Adam
from keras.layers.advanced_activations import ELU
from keras.layers.normalization import BatchNormalization
from keras import backend as K
from keras.regularizers import l2

import tensorflow as tf
# Out:
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
train_data_dirpath = "/data/cityscapes_dataset/leftImg8bit/train" #"/data2/cityscapes_dataset/leftImg8bit/train"
train_all_fnames = []
#all_fnames_list = []
for subfolder_name in os.listdir(train_data_dirpath):
    #print(subfolder_name)
    output_fnames = [join(train_data_dirpath, subfolder_name, fname) for fname in os.listdir(join(train_data_dirpath, subfolder_name))]
    fnames_list = [fname for fname in os.listdir(join(train_data_dirpath, subfolder_name))]
    train_all_fnames+=output_fnames
    #all_fnames_list+=fnames_list
#print(train_all_fnames)
#print(all_fnames_list)

# %%
len(train_all_fnames) # number of training images
# Out:
# 2975

# %%
val_data_dirpath = "/data/cityscapes_dataset/leftImg8bit/val"
val_all_fnames = []
#all_fnames_list = []
for subfolder_name in os.listdir(val_data_dirpath):
    #print(subfolder_name)
    output_fnames = [join(val_data_dirpath, subfolder_name, fname) for fname in os.listdir(join(val_data_dirpath, subfolder_name))]
    fnames_list = [fname for fname in os.listdir(join(val_data_dirpath, subfolder_name))]
    val_all_fnames+=output_fnames
    #all_fnames_list+=fnames_list
#print(val_all_fnames)

# %%
len(val_all_fnames)
# Out:
# 500

# %%
"aachen_000000_000019.png"

# %%
"/data2/cityscapes_dataset/leftImg8bit/train/bochum/bochum_000000_021393_leftImg8bit.png"

# %%
"""
with open('/data2/cityscapes_dataset/val_images_labels.txt', 'w') as f:
    for item in train_all_fnames:
        label_name = "/data2/cityscapes_dataset/gtFine_trainId/" + item.split("/")[-1][0:-16] + ".png"
        f.write("%s %s\n" % (item, label_name))
"""

# %%
#!cat your_file.txt

# %% [markdown]
# ### Not use pretrained model, just build a blank VGG16 (FCN32s)

# %%
input_shape = (512, 512, 3)
img_input = Input(shape=input_shape)

weight_decay = 0.01
# block1 
x = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block1_conv1',
          kernel_regularizer=l2(weight_decay))(img_input)
x = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block1_conv2',
          kernel_regularizer=l2(weight_decay))(x)
x = MaxPool2D(pool_size=(2,2), strides=(2,2), name='block1_pool')(x)

# block2
x = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block2_conv1',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block2_conv2',
          kernel_regularizer=l2(weight_decay))(x)
x = MaxPool2D(pool_size=(2,2), strides=(2,2), name='block2_pool')(x)

# block3
x = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block3_conv1',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block3_conv2',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block3_conv3',
          kernel_regularizer=l2(weight_decay))(x)
x = MaxPool2D(pool_size=(2,2), strides=(2,2), name='block3_pool')(x)

# block4
x = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block4_conv1',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block4_conv2',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block4_conv3',
          kernel_regularizer=l2(weight_decay))(x)
x = MaxPool2D(pool_size=(2,2), strides=(2,2), name='block4_pool')(x)

# block5
x = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block5_conv1',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block5_conv2',
          kernel_regularizer=l2(weight_decay))(x)
x = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', name='block5_conv3',
          kernel_regularizer=l2(weight_decay))(x)
x = MaxPool2D(pool_size=(2,2), strides=(2,2), name='block5_pool')(x)

# fully convolutional
x = Conv2D(filters=4096, kernel_size=(7,7), activation='relu', padding='same', name='fc1', 
           kernel_regularizer=l2(weight_decay))(x)
x = Dropout(0.5)(x)
x = Conv2D(filters=4096,kernel_size=(1,1), activation='relu', padding='same', name='fc2',
           kernel_regularizer=l2(weight_decay))(x)
x = Dropout(0.5)(x)

# segment
x = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', padding='same',
           kernel_regularizer=l2(weight_decay))(x)

# upsample x 32
x = UpSampling2D(size=(32,32))(x)
x = Reshape((512*512, 20))(x)

# %% [markdown]
# ### Not use pretrained model, just build a blank VGG16 (FCN16s)

# %%
input_shape = (512, 512, 3)
newInput = Input(shape=input_shape)

# %% [markdown]
# ### Not use pretrained mode (blank VGG16), deeplab v2 (with mutliple-scale based on atrous spatial pyramid pooling)

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, AtrousConv2D, MaxPool2D, merge, ZeroPadding2D, Dropout, UpSampling2D
# Not use padding="same" or "valid" in Conv2D(), use ZeroPadding2D instead

# %%
input_shape = (512, 512, 3)
img_input = Input(shape=input_shape)

# %%
# block1
h = ZeroPadding2D(padding=(1,1))(img_input)
h = Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='block1_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='block1_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block2
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='block2_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='block2_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block3
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block4
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(1,1))(h)

# block5 (start to use Atrous convolution)
h = ZeroPadding2D(padding=(2,2))(h) # padding <-> atrous_rate
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv1')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv2')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(1,1))(h)

# atrous (four scales)

# atrous rate = 6
b1 = ZeroPadding2D(padding=(6,6))(h) # padding <-> atrous_rate
b1 = AtrousConv2D(filters=1024, atrous_rate=(6,6), kernel_size=(3,3), activation='relu', name='fc6_scale1')(b1)
b1 = Dropout(0.5)(b1)
b1 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale1')(b1) # normal Conv2D
b1 = Dropout(0.5)(b1)
b1 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale1')(b1)# normal Conv2D

# atrous rate = 12
b2 = ZeroPadding2D(padding=(12,12))(b1)
b2 = AtrousConv2D(filters=1024, atrous_rate=(12,12), kernel_size=(3,3), activation='relu', name='fc6_scale2')(b2)
b2 = Dropout(0.5)(b2)
b2 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale2')(b2)
b2 = Dropout(0.5)(b2)
b2 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale2')(b2)
                   
# atrous rate = 18
b3 = ZeroPadding2D(padding=(18,18))(b2)
b3 = AtrousConv2D(filters=1024, atrous_rate=(18,18), kernel_size=(3,3), activation='relu', name='fc6_scale3')(b3)
b3 = Dropout(0.5)(b3)
b3 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale3')(b3)
b3 = Dropout(0.5)(b3)
b3 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale3')(b3)
                   
# atrous rate = 24
b4 = ZeroPadding2D(padding=(24,24))(b3)
b4 = AtrousConv2D(filters=1024, atrous_rate=(24,24), kernel_size=(3,3), activation='relu', name='fc6_scale4')(b4)
b4 = Dropout(0.5)(b4)
b4 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale4')(b4)
b4 = Dropout(0.5)(b4)
b4 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale4')(b4)

# merge four scales
s = merge([b1, b2, b3, b4], mode='sum')
out = UpSampling2D(size=(8,8))(s)

x = Reshape((512*512, 20))(out)
# Out:
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/legacy/layers.py:755: UserWarning: The `AtrousConvolution2D` layer  has been deprecated. Use instead the `Conv2D` layer with the `dilation_rate` argument.
#   warnings.warn('The `AtrousConvolution2D` layer '
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:82: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-193ff897ef5c> in <module>()
#      83 out = UpSampling2D(size=(8,8))(s)
#      84
# ---> 85 x = Reshape((512*512, 20))(out)
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     619             # Infering the output shape is only relevant for Theano.
#     620             if all([s is not None for s in _to_list(input_shape)]):
# --> 621                 output_shape = self.compute_output_shape(input_shape)
#     622             else:
#     623                 if isinstance(input_shape, list):
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/layers/core.py in compute_output_shape(self, input_shape)
#     374     def compute_output_shape(self, input_shape):
#     375         return (input_shape[0],) + self._fix_unknown_dimension(
# --> 376             input_shape[1:], self.target_shape)
#     377
#     378     def call(self, inputs):
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/layers/core.py in _fix_unknown_dimension(self, input_shape, output_shape)
#     368             output_shape[unknown] = original // known
#     369         elif original != known:
# --> 370             raise ValueError(msg)
#     371
#     372         return tuple(output_shape)
#
# ValueError: total size of new array must be unchanged

# %% [markdown]
# ### Not use pretrained mode (blank VGG19), deeplab v2 (with mutliple-scale based on atrous spatial pyramid pooling)

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, AtrousConv2D, MaxPool2D, merge, ZeroPadding2D, Dropout, UpSampling2D

input_shape = (512, 512, 3)
img_input = Input(shape=input_shape)

# block1
h = ZeroPadding2D(padding=(1,1))(img_input)
h = Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='block1_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='block1_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block2
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='block2_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='block2_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block3
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv4')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block4
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv4')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(1,1))(h)

# block5 (start to use Atrous convolution)
h = ZeroPadding2D(padding=(2,2))(h) # padding <-> atrous_rate
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv1')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv2')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv3')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv4')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(1,1))(h)

# atrous (four scales)

# atrous rate = 6
b1 = ZeroPadding2D(padding=(6,6))(h) # padding <-> atrous_rate
b1 = AtrousConv2D(filters=1024, atrous_rate=(6,6), kernel_size=(3,3), activation='relu', name='fc6_scale1')(b1)
b1 = Dropout(0.5)(b1)
b1 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale1')(b1) # normal Conv2D
b1 = Dropout(0.5)(b1)
b1 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale1')(b1)# normal Conv2D

# atrous rate = 12
b2 = ZeroPadding2D(padding=(12,12))(b1)
b2 = AtrousConv2D(filters=1024, atrous_rate=(12,12), kernel_size=(3,3), activation='relu', name='fc6_scale2')(b2)
b2 = Dropout(0.5)(b2)
b2 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale2')(b2)
b2 = Dropout(0.5)(b2)
b2 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale2')(b2)
                   
# atrous rate = 18
b3 = ZeroPadding2D(padding=(18,18))(b2)
b3 = AtrousConv2D(filters=1024, atrous_rate=(18,18), kernel_size=(3,3), activation='relu', name='fc6_scale3')(b3)
b3 = Dropout(0.5)(b3)
b3 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale3')(b3)
b3 = Dropout(0.5)(b3)
b3 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale3')(b3)
                   
# atrous rate = 24
b4 = ZeroPadding2D(padding=(24,24))(b3)
b4 = AtrousConv2D(filters=1024, atrous_rate=(24,24), kernel_size=(3,3), activation='relu', name='fc6_scale4')(b4)
b4 = Dropout(0.5)(b4)
b4 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale4')(b4)
b4 = Dropout(0.5)(b4)
b4 = Conv2D(filters=20, kernel_size=(1,1), activation='softmax', name='fc8_scale4')(b4)

# merge four scales
s = merge([b1, b2, b3, b4], mode='sum')
out = UpSampling2D(size=(8,8))(s)

x = Reshape((512*512, 20))(out)

# %%
img_h=512 #1024
img_w=1024 #2048
n_label=20

# %%
input_shape = (img_h, img_w, 3)
img_input = Input(shape=input_shape)

# block1
h = ZeroPadding2D(padding=(1,1))(img_input)
h = Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='block1_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='block1_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block2
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='block2_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='block2_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block3
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=256, kernel_size=(3,3), activation='relu', name='block3_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(2,2))(h)

# block4
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv1')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv2')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = Conv2D(filters=512, kernel_size=(3,3), activation='relu', name='block4_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(1,1))(h)

# block5 (start to use Atrous convolution)
h = ZeroPadding2D(padding=(2,2))(h) # padding <-> atrous_rate
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv1')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv2')(h)
h = ZeroPadding2D(padding=(2,2))(h)
h = AtrousConv2D(filters=512, atrous_rate=(2,2), kernel_size=(3,3), activation='relu', name='block5_conv3')(h)
h = ZeroPadding2D(padding=(1,1))(h)
h = MaxPool2D(pool_size=(3,3), strides=(1,1))(h)

# atrous (four scales)

# atrous rate = 6
b1 = ZeroPadding2D(padding=(6,6))(h) # padding <-> atrous_rate
b1 = AtrousConv2D(filters=1024, atrous_rate=(6,6), kernel_size=(3,3), activation='relu', name='fc6_scale1')(b1)
b1 = Dropout(0.5)(b1)
b1 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale1')(b1) # normal Conv2D
b1 = Dropout(0.5)(b1)
b1 = Conv2D(filters=n_label, kernel_size=(1,1), activation='softmax', name='fc8_scale1')(b1)# normal Conv2D

# atrous rate = 12
b2 = ZeroPadding2D(padding=(12,12))(b1)
b2 = AtrousConv2D(filters=1024, atrous_rate=(12,12), kernel_size=(3,3), activation='relu', name='fc6_scale2')(b2)
b2 = Dropout(0.5)(b2)
b2 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale2')(b2)
b2 = Dropout(0.5)(b2)
b2 = Conv2D(filters=n_label, kernel_size=(1,1), activation='softmax', name='fc8_scale2')(b2)
                   
# atrous rate = 18
b3 = ZeroPadding2D(padding=(18,18))(b2)
b3 = AtrousConv2D(filters=1024, atrous_rate=(18,18), kernel_size=(3,3), activation='relu', name='fc6_scale3')(b3)
b3 = Dropout(0.5)(b3)
b3 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale3')(b3)
b3 = Dropout(0.5)(b3)
b3 = Conv2D(filters=n_label, kernel_size=(1,1), activation='softmax', name='fc8_scale3')(b3)
                   
# atrous rate = 24
b4 = ZeroPadding2D(padding=(24,24))(b3)
b4 = AtrousConv2D(filters=1024, atrous_rate=(24,24), kernel_size=(3,3), activation='relu', name='fc6_scale4')(b4)
b4 = Dropout(0.5)(b4)
b4 = Conv2D(filters=1024, kernel_size=(1,1), activation='relu', name='fc7_scale4')(b4)
b4 = Dropout(0.5)(b4)
b4 = Conv2D(filters=n_label, kernel_size=(1,1), activation='softmax', name='fc8_scale4')(b4)

# merge four scales
s = merge([b1, b2, b3, b4], mode='sum')
out = UpSampling2D(size=(8,8))(s)

x = Reshape((img_h*img_w, n_label))(out)

# construct final model
model = Model(inputs=img_input, outputs=x)
# Out:
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/legacy/layers.py:755: UserWarning: The `AtrousConvolution2D` layer  has been deprecated. Use instead the `Conv2D` layer with the `dilation_rate` argument.
#   warnings.warn('The `AtrousConvolution2D` layer '
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:85: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 512, 1024, 3)  0
# ____________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2D (None, 514, 1026, 3)  0           input_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 512, 1024, 64) 1792        zero_padding2d_23[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2D (None, 514, 1026, 64) 0           block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Conv2D)            (None, 512, 1024, 64) 36928       zero_padding2d_24[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2D (None, 514, 1026, 64) 0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)   (None, 256, 512, 64)  0           zero_padding2d_25[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2D (None, 258, 514, 64)  0           max_pooling2d_6[0][0]
# ____________________________________________________________________________________________________
# block2_conv1 (Conv2D)            (None, 256, 512, 128) 73856       zero_padding2d_26[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2D (None, 258, 514, 128) 0           block2_conv1[0][0]
# ____________________________________________________________________________________________________
# block2_conv2 (Conv2D)            (None, 256, 512, 128) 147584      zero_padding2d_27[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2D (None, 258, 514, 128) 0           block2_conv2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)   (None, 128, 256, 128) 0           zero_padding2d_28[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2D (None, 130, 258, 128) 0           max_pooling2d_7[0][0]
# ____________________________________________________________________________________________________
# block3_conv1 (Conv2D)            (None, 128, 256, 256) 295168      zero_padding2d_29[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2D (None, 130, 258, 256) 0           block3_conv1[0][0]
# ____________________________________________________________________________________________________
# block3_conv2 (Conv2D)            (None, 128, 256, 256) 590080      zero_padding2d_30[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2D (None, 130, 258, 256) 0           block3_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_conv3 (Conv2D)            (None, 128, 256, 256) 590080      zero_padding2d_31[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2D (None, 130, 258, 256) 0           block3_conv3[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)   (None, 64, 128, 256)  0           zero_padding2d_32[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2D (None, 66, 130, 256)  0           max_pooling2d_8[0][0]
# ____________________________________________________________________________________________________
# block4_conv1 (Conv2D)            (None, 64, 128, 512)  1180160     zero_padding2d_33[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2D (None, 66, 130, 512)  0           block4_conv1[0][0]
# ____________________________________________________________________________________________________
# block4_conv2 (Conv2D)            (None, 64, 128, 512)  2359808     zero_padding2d_34[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_35 (ZeroPadding2D (None, 66, 130, 512)  0           block4_conv2[0][0]
# ____________________________________________________________________________________________________
# block4_conv3 (Conv2D)            (None, 64, 128, 512)  2359808     zero_padding2d_35[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_36 (ZeroPadding2D (None, 66, 130, 512)  0           block4_conv3[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)   (None, 64, 128, 512)  0           zero_padding2d_36[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_37 (ZeroPadding2D (None, 68, 132, 512)  0           max_pooling2d_9[0][0]
# ____________________________________________________________________________________________________
# block5_conv1 (Conv2D)            (None, 64, 128, 512)  2359808     zero_padding2d_37[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_38 (ZeroPadding2D (None, 68, 132, 512)  0           block5_conv1[0][0]
# ____________________________________________________________________________________________________
# block5_conv2 (Conv2D)            (None, 64, 128, 512)  2359808     zero_padding2d_38[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_39 (ZeroPadding2D (None, 68, 132, 512)  0           block5_conv2[0][0]
# ____________________________________________________________________________________________________
# block5_conv3 (Conv2D)            (None, 64, 128, 512)  2359808     zero_padding2d_39[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_40 (ZeroPadding2D (None, 66, 130, 512)  0           block5_conv3[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D)  (None, 64, 128, 512)  0           zero_padding2d_40[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_41 (ZeroPadding2D (None, 76, 140, 512)  0           max_pooling2d_10[0][0]
# ____________________________________________________________________________________________________
# fc6_scale1 (Conv2D)              (None, 64, 128, 1024) 4719616     zero_padding2d_41[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 64, 128, 1024) 0           fc6_scale1[0][0]
# ____________________________________________________________________________________________________
# fc7_scale1 (Conv2D)              (None, 64, 128, 1024) 1049600     dropout_9[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 64, 128, 1024) 0           fc7_scale1[0][0]
# ____________________________________________________________________________________________________
# fc8_scale1 (Conv2D)              (None, 64, 128, 20)   20500       dropout_10[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_42 (ZeroPadding2D (None, 88, 152, 20)   0           fc8_scale1[0][0]
# ____________________________________________________________________________________________________
# fc6_scale2 (Conv2D)              (None, 64, 128, 1024) 185344      zero_padding2d_42[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)             (None, 64, 128, 1024) 0           fc6_scale2[0][0]
# ____________________________________________________________________________________________________
# fc7_scale2 (Conv2D)              (None, 64, 128, 1024) 1049600     dropout_11[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, 64, 128, 1024) 0           fc7_scale2[0][0]
# ____________________________________________________________________________________________________
# fc8_scale2 (Conv2D)              (None, 64, 128, 20)   20500       dropout_12[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_43 (ZeroPadding2D (None, 100, 164, 20)  0           fc8_scale2[0][0]
# ____________________________________________________________________________________________________
# fc6_scale3 (Conv2D)              (None, 64, 128, 1024) 185344      zero_padding2d_43[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 64, 128, 1024) 0           fc6_scale3[0][0]
# ____________________________________________________________________________________________________
# fc7_scale3 (Conv2D)              (None, 64, 128, 1024) 1049600     dropout_13[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 64, 128, 1024) 0           fc7_scale3[0][0]
# ____________________________________________________________________________________________________
# fc8_scale3 (Conv2D)              (None, 64, 128, 20)   20500       dropout_14[0][0]
# ____________________________________________________________________________________________________
# zero_padding2d_44 (ZeroPadding2D (None, 112, 176, 20)  0           fc8_scale3[0][0]
# ____________________________________________________________________________________________________
# fc6_scale4 (Conv2D)              (None, 64, 128, 1024) 185344      zero_padding2d_44[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 64, 128, 1024) 0           fc6_scale4[0][0]
# ____________________________________________________________________________________________________
# fc7_scale4 (Conv2D)              (None, 64, 128, 1024) 1049600     dropout_15[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 64, 128, 1024) 0           fc7_scale4[0][0]
# ____________________________________________________________________________________________________
# fc8_scale4 (Conv2D)              (None, 64, 128, 20)   20500       dropout_16[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 64, 128, 20)   0           fc8_scale1[0][0]
#                                                                    fc8_scale2[0][0]
#                                                                    fc8_scale3[0][0]
#                                                                    fc8_scale4[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 512, 1024, 20) 0           merge_2[0][0]
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 524288, 20)    0           up_sampling2d_2[0][0]
# ====================================================================================================
# Total params: 24,270,736
# Trainable params: 24,270,736
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
# construct final model
#model = Model(inputs=img_input, outputs=x)

model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['acc'])

# %% [markdown]
# ### Load imagenet pretrained VGG16 model

# %%
from keras.applications import VGG16

conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(512, 512, 3))

# %%
# extend the conv_base
from keras import models
model = models.Sequential()
model.add(conv_base)

# %%
from keras.regularizers import l2
weight_decay = 0.0 # 0.01

# %%
# append fully convolutional layers
model.add(Conv2D(filters=4096, kernel_size=(7,7), activation='relu', padding='same', name='fc1', 
           kernel_regularizer=l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Conv2D(filters=4096, kernel_size=(1,1), activation='relu', padding='same', name='fc2', 
           kernel_regularizer=l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Conv2D(filters=20, kernel_size=(1,1), activation='softmax', padding='same', # output is prob.
           kernel_regularizer=l2(weight_decay)))
# upsample x 32
model.add(UpSampling2D(size=(32,32))) # get (512,512,4096)
model.add(Reshape((512*512, 20)))

"""
# upsample x 32
model.add(UpSampling2D(size=(32,32))) # get (512,512,4096)

model.add(Conv2D(filters=20, kernel_size=(1,1), activation='softmax', padding='same', # output is prob.
           kernel_regularizer=l2(weight_decay)))

model.add(Reshape((512*512, 20)))


"""
# Out:
# "\n# upsample x 32\nmodel.add(UpSampling2D(size=(32,32))) # get (512,512,4096)\n\nmodel.add(Conv2D(filters=20, kernel_size=(1,1), activation='softmax', padding='same', # output is prob.\n           kernel_regularizer=l2(weight_decay)))\n\nmodel.add(Reshape((512*512, 20)))\n\n\n"

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 512, 512, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 512, 512, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 512, 512, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 256, 256, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 256, 256, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 256, 256, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 128, 128, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 128, 128, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 128, 128, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 128, 128, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 64, 64, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 64, 64, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 32, 32, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# fc1 (Conv2D)                 (None, 16, 16, 4096)      102764544
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 16, 16, 4096)      0
# _________________________________________________________________
# fc2 (Conv2D)                 (None, 16, 16, 4096)      16781312
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16, 16, 4096)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 20)        81940
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 512, 512, 20)      0
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 262144, 20)        0
# =================================================================
# Total params: 134,342,484
# Trainable params: 134,342,484
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['acc'])

# %%
"""
model.add(Reshape((img_w*img_h, n_label)))  
#axis=1和axis=2互换位置，等同于np.swapaxes(layer,1,2)  
#model.add(Permute((2,1)))  
model.add(Activation('softmax'))  
model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])  
model.summary() 
"""

# %% [markdown]
# ### Construct network model: FCN (VGG16 imagenet pretrained)

# %%
img_h=256
img_w=256
n_label=20
from keras.models import Sequential
def SegNet():  
    model = Sequential()  
    #encoder  
    model.add(Conv2D(64,(3,3),strides=(1,1),input_shape=(img_h,img_w,3),padding='same',
                     activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu'))  
    model.add(BatchNormalization())  
    model.add(MaxPooling2D(pool_size=(2,2)))  
    #(128,128)  
    model.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(MaxPooling2D(pool_size=(2, 2)))  
    #(64,64)  
    model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(MaxPooling2D(pool_size=(2, 2)))  
    #(32,32)  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(MaxPooling2D(pool_size=(2, 2)))  
    #(16,16)  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(MaxPooling2D(pool_size=(2, 2)))  
    #(8,8)  
    #decoder  
    model.add(UpSampling2D(size=(2,2)))  
    #(16,16)  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(UpSampling2D(size=(2, 2)))  
    #(32,32)  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(UpSampling2D(size=(2, 2)))  
    #(64,64)  
    model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(UpSampling2D(size=(2, 2)))  
    #(128,128)  
    model.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(UpSampling2D(size=(2, 2)))  
    #(256,256)  
    model.add(Conv2D(64, (3, 3), strides=(1, 1), input_shape=(img_w, img_h,3), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu'))  
    model.add(BatchNormalization())  
    model.add(Conv2D(n_label, (1, 1), strides=(1, 1), padding='same'))  
    model.add(Reshape((img_w*img_h, n_label)))  
    #axis=1和axis=2互换位置，等同于np.swapaxes(layer,1,2)  
    #model.add(Permute((2,1)))  
    model.add(Activation('softmax'))  
    model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])  
    model.summary()  
    return model

# %%
#size = 224 # crop size is 224
n_cls = 20 # number of classes is 3

# %%
# model = get_unet(224, n_cls)
model = SegNet()
#model.compile(optimizer=Adam(lr=0.01), loss=my_bce)#, metrics=[my_acc])
# model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 256, 256, 64)      1792
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 128, 128, 128)     73856
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 128, 128, 128)     147584
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 64, 64, 256)       295168
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 32, 32, 512)       1180160
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 32, 32, 512)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 64, 64, 512)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 64, 64, 256)       1179904
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 128, 128, 256)     0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 128, 128, 128)     295040
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 128, 128, 128)     147584
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 256, 256, 128)     0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 256, 256, 64)      73792
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 256, 256, 20)      1300
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 65536, 20)         0
# _________________________________________________________________
# activation_1 (Activation)    (None, 65536, 20)         0
# =================================================================
# Total params: 31,822,036
# Trainable params: 31,805,140
# Non-trainable params: 16,896
# _________________________________________________________________

# %%
img_h=512 #1024
img_w=1024 #2048
n_label=20

# %%
"""
def get_train_val(val_rate = 0.25):
    train_url = []    
    train_set = []
    val_set  = []
    for pic in os.listdir(filepath + 'src'):
        train_url.append(pic)
    random.shuffle(train_url)
    total_num = len(train_url)
    val_num = int(val_rate * total_num)
    for i in range(len(train_url)):
        if i < val_num:
            val_set.append(train_url[i]) 
        else:
            train_set.append(train_url[i])
    return train_set,val_set
"""  

from keras.preprocessing import image
from keras.utils import to_categorical
# data for training  
def generateTrainData(batch_size):  
    #print 'generateData...'
    while True:  
        train_data = []  
        train_label = []  
        batch = 0  
        #for i in (range(len(data))): 
        for i, train_fname in enumerate(train_all_fnames):
            #url = data[i]
            batch += 1 
            #print (filepath + 'src/' + url)
            #img = load_img(filepath + 'src/' + url, target_size=(img_w, img_h))  
            #img = load_img(filepath + 'src/' + url)
            img = image.load_img(train_fname, target_size=(img_h, img_w, 3))
            img = image.img_to_array(img) 
            # print img
            # print img.shape  
            train_data.append(img)  
            #label = load_img(filepath + 'label/' + url, target_size=(img_w, img_h),grayscale=True)
            train_label_name = "/data/cityscapes_dataset/gtFine_trainId/" + train_fname.split("/")[-1][0:-16] + ".png"
            label = image.load_img(train_label_name, grayscale=True, target_size=(img_h, img_w))
            label = image.img_to_array(label).reshape((img_w * img_h,)) # reshape to 1-D vector  
            # print label.shape  
            train_label.append(label)  
            if batch % batch_size==0: 
                #print 'get enough bacth!\n'
                train_data = np.array(train_data)  
                train_label = np.array(train_label).flatten()  
                #train_label = labelencoder.transform(train_label)  
                train_label = to_categorical(train_label, num_classes=n_label)  
                train_label = train_label.reshape((batch_size, img_w * img_h, n_label))  
                yield (train_data,train_label)  
                train_data = []  
                train_label = []  
                batch = 0

# %%
def generateValData(batch_size):  
    #print 'generateData...'
    while True:  
        val_data = []  
        val_label = []  
        batch = 0  
        #for i in (range(len(data))): 
        for i, val_fname in enumerate(val_all_fnames):
            #url = data[i]
            batch += 1 
            #print (filepath + 'src/' + url)
            #img = load_img(filepath + 'src/' + url, target_size=(img_w, img_h))  
            #img = load_img(filepath + 'src/' + url)
            img = image.load_img(val_fname, target_size=(img_h, img_w, 3))
            img = image.img_to_array(img) 
            # print img
            # print img.shape  
            val_data.append(img)  
            #label = load_img(filepath + 'label/' + url, target_size=(img_w, img_h),grayscale=True)
            val_label_name = "/data/cityscapes_dataset/gtFine_trainId/" + val_fname.split("/")[-1][0:-16] + ".png"
            label = image.load_img(val_label_name, grayscale=True, target_size=(img_h, img_w))
            label = image.img_to_array(label).reshape((img_w * img_h,)) # reshape to 1-D vector  
            # print label.shape  
            val_label.append(label)  
            if batch % batch_size==0: 
                #print 'get enough bacth!\n'
                val_data = np.array(val_data)  
                val_label = np.array(val_label).flatten()  
                #val_label = labelencoder.transform(val_label)  
                val_label = to_categorical(val_label, num_classes=n_label)  
                val_label = val_label.reshape((batch_size, img_w * img_h, n_label))  
                yield (val_data,val_label)  
                val_data = []  
                val_label = []  
                batch = 0

# %%
# add callbacks
import keras

# Callbacks are passed to the model fit the `callbacks` argument in `fit`,
# which takes a list of callbacks. You can pass any number of callbacks.
callbacks_list = [
    # This callback will interrupt training when we have stopped improving
    keras.callbacks.EarlyStopping(
              monitor='val_loss',  # This callback will monitor the validation loss of the model               
              patience=5,                  # Training will be interrupted when the accuracy
                                           # has stopped improving for *more* than 1 epochs (i.e. 2 epochs)
              ),
    # This callback will save the current weights after every epoch
    keras.callbacks.ModelCheckpoint(
              filepath='model_deeplabv2_512x1024.h5', # Path to the destination model file
              # The two arguments below mean that we will not overwrite the
              # model file unless `val_loss` has improved, which
              # allows us to keep the best model every seen during training.
              monitor='val_loss',
              save_best_only=True,
              )
]

# %%
EPOCHS = 100
BS = 1

history = model.fit_generator(generator=generateTrainData(BS),steps_per_epoch=2975,epochs=EPOCHS,verbose=1,  
                validation_data=generateValData(BS),validation_steps=500, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 2975/2975 [==============================] - 819s - loss: 1.7936 - acc: 0.5901 - val_loss: 1.4720 - val_acc: 0.6403
# Epoch 2/100
# 2975/2975 [==============================] - 819s - loss: 1.2969 - acc: 0.6597 - val_loss: 1.1912 - val_acc: 0.6477
# Epoch 3/100
# 2975/2975 [==============================] - 819s - loss: 1.1336 - acc: 0.6450 - val_loss: 1.0798 - val_acc: 0.6529
# Epoch 4/100
# 2975/2975 [==============================] - 822s - loss: 1.0136 - acc: 0.6837 - val_loss: 1.0085 - val_acc: 0.7088
# Epoch 5/100
# 2975/2975 [==============================] - 820s - loss: 0.9323 - acc: 0.7301 - val_loss: 0.9482 - val_acc: 0.7294
# Epoch 6/100
# 2975/2975 [==============================] - 821s - loss: 0.8900 - acc: 0.7385 - val_loss: 0.9009 - val_acc: 0.7396
# Epoch 7/100
# 2975/2975 [==============================] - 822s - loss: 0.8274 - acc: 0.7569 - val_loss: 0.8633 - val_acc: 0.7510
# Epoch 8/100
# 2975/2975 [==============================] - 820s - loss: 0.7830 - acc: 0.7702 - val_loss: 0.8425 - val_acc: 0.7577
# Epoch 9/100
# 2975/2975 [==============================] - 820s - loss: 0.7639 - acc: 0.7753 - val_loss: 0.8178 - val_acc: 0.7621
# Epoch 10/100
# 2975/2975 [==============================] - 821s - loss: 0.7376 - acc: 0.7814 - val_loss: 0.8003 - val_acc: 0.7641
# Epoch 11/100
# 2975/2975 [==============================] - 821s - loss: 0.7091 - acc: 0.7878 - val_loss: 0.7626 - val_acc: 0.7743
# Epoch 12/100
# 2975/2975 [==============================] - 821s - loss: 0.6843 - acc: 0.7931 - val_loss: 0.7413 - val_acc: 0.7788
# Epoch 13/100
# 2975/2975 [==============================] - 823s - loss: 0.6647 - acc: 0.7965 - val_loss: 0.7188 - val_acc: 0.7829
# Epoch 14/100
# 2975/2975 [==============================] - 822s - loss: 0.6418 - acc: 0.8008 - val_loss: 0.7156 - val_acc: 0.7855
# Epoch 15/100
# 2975/2975 [==============================] - 821s - loss: 0.6210 - acc: 0.8051 - val_loss: 0.7012 - val_acc: 0.7880
# Epoch 16/100
# 2975/2975 [==============================] - 821s - loss: 0.5942 - acc: 0.8168 - val_loss: 0.6657 - val_acc: 0.8064
# Epoch 17/100
# 2975/2975 [==============================] - 821s - loss: 0.5592 - acc: 0.8302 - val_loss: 0.6427 - val_acc: 0.8107
# Epoch 18/100
# 2975/2975 [==============================] - 821s - loss: 0.5424 - acc: 0.8350 - val_loss: 0.6368 - val_acc: 0.8130
# Epoch 19/100
# 2975/2975 [==============================] - 821s - loss: 0.5268 - acc: 0.8396 - val_loss: 0.6297 - val_acc: 0.8144
# Epoch 20/100
# 2975/2975 [==============================] - 821s - loss: 0.5161 - acc: 0.8427 - val_loss: 0.6292 - val_acc: 0.8162
# Epoch 21/100
# 2975/2975 [==============================] - 820s - loss: 0.5207 - acc: 0.8426 - val_loss: 0.6227 - val_acc: 0.8170
# Epoch 22/100
# 2975/2975 [==============================] - 821s - loss: 0.5048 - acc: 0.8462 - val_loss: 0.6154 - val_acc: 0.8206
# Epoch 23/100
# 2975/2975 [==============================] - 822s - loss: 0.4829 - acc: 0.8517 - val_loss: 0.6131 - val_acc: 0.8228
# Epoch 24/100
# 2975/2975 [==============================] - 821s - loss: 0.4797 - acc: 0.8523 - val_loss: 0.6098 - val_acc: 0.8239
# Epoch 25/100
# 2975/2975 [==============================] - 820s - loss: 0.4831 - acc: 0.8514 - val_loss: 0.6020 - val_acc: 0.8224
# Epoch 26/100
# 2975/2975 [==============================] - 836s - loss: 0.4619 - acc: 0.8561 - val_loss: 0.5941 - val_acc: 0.8254
# Epoch 27/100
# 2975/2975 [==============================] - 827s - loss: 0.4440 - acc: 0.8601 - val_loss: 0.5960 - val_acc: 0.8269
# Epoch 28/100
# 2975/2975 [==============================] - 822s - loss: 0.4377 - acc: 0.8611 - val_loss: 0.5938 - val_acc: 0.8278
# Epoch 29/100
# 2975/2975 [==============================] - 823s - loss: 0.4349 - acc: 0.8614 - val_loss: 0.5897 - val_acc: 0.8285
# Epoch 30/100
# 2975/2975 [==============================] - 822s - loss: 0.4208 - acc: 0.8644 - val_loss: 0.5806 - val_acc: 0.8295
# Epoch 31/100
# 2975/2975 [==============================] - 824s - loss: 0.4100 - acc: 0.8671 - val_loss: 0.5798 - val_acc: 0.8298
# Epoch 32/100
# 2975/2975 [==============================] - 828s - loss: 0.4215 - acc: 0.8641 - val_loss: 0.5878 - val_acc: 0.8301
# Epoch 33/100
# 2975/2975 [==============================] - 829s - loss: 0.3948 - acc: 0.8711 - val_loss: 0.5833 - val_acc: 0.8313
# Epoch 34/100
# 2975/2975 [==============================] - 830s - loss: 0.3845 - acc: 0.8738 - val_loss: 0.5849 - val_acc: 0.8322
# Epoch 35/100
# 2975/2975 [==============================] - 827s - loss: 0.3772 - acc: 0.8758 - val_loss: 0.5865 - val_acc: 0.8323
# Epoch 36/100
# 2975/2975 [==============================] - 827s - loss: 0.3703 - acc: 0.8775 - val_loss: 0.5852 - val_acc: 0.8329
# Epoch 37/100
# 2975/2975 [==============================] - 827s - loss: 0.3637 - acc: 0.8788 - val_loss: 0.5870 - val_acc: 0.8332

# %%
input_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1f1a64534a5b> in <module>()
# ----> 1 input_1
#
# NameError: name 'input_1' is not defined

# %%
history.historytory

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = 37
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
#plt.plot(np.arange(0, N), history.history["acc"], label="train_acc")
#plt.plot(np.arange(0, N), history.history["acc"], label="train_acc")
#plt.plot(np.arange(0, N), history["val_acc"], label="val_acc")
plt.title("Training and validation Loss on deeplabv2.")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.savefig("deeplabv2_512x1024_loss")

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = 37
plt.plot(np.arange(0, N), history.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_acc"], label="val_acc")
#plt.plot(np.arange(0, N), history["val_acc"], label="val_acc")
plt.title("Training and validation accurracy on deeplabv2.")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.savefig("deeplabv2_512x1024_acc")

# %%
# save model
model.save('../models/segnet_r256_e3.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-e4a996e756d4> in <module>()
#       1 # save model
# ----> 2 model.save('../models/segnet_r256_e3.h5')
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/engine/topology.py in save(self, filepath, overwrite, include_optimizer)
#    2551         """
#    2552         from ..models import save_model
# -> 2553         save_model(self, filepath, overwrite, include_optimizer)
#    2554
#    2555     def save_weights(self, filepath, overwrite=True):
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/models.py in save_model(model, filepath, overwrite, include_optimizer)
#     100             return
#     101
# --> 102     with h5py.File(filepath, mode='w') as f:
#     103         f.attrs['keras_version'] = str(keras_version).encode('utf8')
#     104         f.attrs['backend'] = K.backend().encode('utf8')
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     103         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     104     elif mode == 'w':
# --> 105         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     106     elif mode == 'a':
#     107         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '../models/segnet_r256_e3.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242)

# %% [markdown]
# ### Perform prediction on test image

# %%
1024/256, 2048/256 # 4, 8

# %%
# Partition the test image (1024, 2048) into 4x8 (256,256)
test_img_slices = []
row_start, column_start = 0, 0
row_end = img_h
column_end = img_w
for i in range(4):
    for j in range(8):        
        test_img_slices.append(test_img[row_start:row_end, column_start:column_end])
        column_start=column_end
        column_end+=img_w
    row_start=row_end
    row_end+=img_h

# %%
input_shape = (1024, 2048, 3)
test_fname = "/data/cityscapes_dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png"
test_img = image.load_img(test_fname)
test_img = image.img_to_array(test_img)

# %%
test_img.shape
# Out:
# (1024, 2048, 3)

# %%
preds = model.predict(np.expand_dims(test_img, axis=0)) # to add batch dim
preds_view = np.reshape(np.argmax(np.squeeze(preds, axis=0), axis=1), (1024, 2048))
plt.imshow(preds_view)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-15f7987178f1> in <module>()
# ----> 1 preds = model.predict(np.expand_dims(test_img, axis=0)) # to add batch dim
#       2 preds_view = np.reshape(np.argmax(np.squeeze(preds, axis=0), axis=1), (1024, 2048))
#       3 plt.imshow(preds_view)
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1693         x = _standardize_input_data(x, self._feed_input_names,
#    1694                                     self._feed_input_shapes,
# -> 1695                                     check_batch_axis=False)
#    1696         if self.stateful:
#    1697             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     142                             ' to have shape ' + str(shapes[i]) +
#     143                             ' but got array with shape ' +
# --> 144                             str(array.shape))
#     145     return arrays
#     146
#
# ValueError: Error when checking : expected input_1 to have shape (None, 512, 512, 3) but got array with shape (1, 1024, 2048, 3)

# %%
# test on resized image 512x512x3
test_fname = "/data/cityscapes_dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png"
test_img = image.load_img(test_fname, target_size=(img_h, img_w, 3))
test_img = image.img_to_array(test_img) # read as numpy array, [0.0 to 255.0]
preds = model.predict(np.expand_dims(test_img, axis=0)) # to add batch dim
preds_view = np.reshape(np.argmax(np.squeeze(preds, axis=0), axis=1), (img_h, img_w))
plt.imshow(preds_view)

# %%
# show test image (resized as 512x1024x3)

# %%
# test on resized image 512x1024x3
test_fname = "/data/cityscapes_dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png"
test_img = image.load_img(test_fname, target_size=(img_h, img_w, 3))
test_img = image.img_to_array(test_img) # read as numpy array, [0.0 to 255.0]
preds = model.predict(np.expand_dims(test_img, axis=0)) # to add batch dim
preds_view = np.reshape(np.argmax(np.squeeze(preds, axis=0), axis=1), (img_h, img_w))
plt.imshow(preds_view)

# %%
test_img.shape, test_img.max(), test_img.min()
# Out:
# ((512, 1024, 3), 255.0, 0.0)

# %%
# show test image (resized as 512x1024x3)
plt.imshow(test_img/255.0)

# %%
# test on full-sized image (1024x2048x3)
test_fname = "/data/cityscapes_dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png"
test_img = image.load_img(test_fname)
test_img = image.img_to_array(test_img) # read as numpy array, [0.0 to 255.0]
preds = model_1024.predict(np.expand_dims(test_img, axis=0)) # to add batch dim
preds_view = np.reshape(np.argmax(np.squeeze(preds, axis=0), axis=1), (1024, 2048))
plt.imshow(preds_view)

# %%
preds_view
# Out:
# array([[ 8,  8,  8, ...,  8,  8,  8],
#        [ 8,  8,  8, ...,  8,  8,  8],
#        [ 8,  8,  8, ...,  8,  8,  8],
#        ...,
#        [ 0,  0,  0, ..., 19, 19, 19],
#        [ 0,  0,  0, ..., 19, 19, 19],
#        [ 0,  0,  0, ..., 19, 19, 19]])

# %%
# Out:
# /root/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.

# %%
preds_view_resized.shape
# Out:
# (1024, 2048)

# %%
import scipy
preds_view_resized=scipy.misc.imresize(preds_view, [1024,2048], interp='bilinear')
plt.imshow(preds_view_resized)

# %%
preds_view_resized
# Out:
# array([[107, 107, 107, ..., 107, 107, 107],
#        [107, 107, 107, ..., 107, 107, 107],
#        [107, 107, 107, ..., 107, 107, 107],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]], dtype=uint8)

# %%
test_img.shape
# Out:
# (512, 512, 3)

# %%
# test_img_ori=mpimg.imread("/data/cityscapes_dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png")

visualize_prediction(test_img, preds_view)

# %%
test_img_ori.shape, test_img_ori.max(), test_img_ori.min()
# Out:
# ((1024, 2048, 3), 1.0, 0.0)

# %%
(preds_view_resized[:,:]==0).shape
# Out:
# (1024, 2048)

# %%
new_image = np.copy(test_img)

# %%
new_image.shape, new_image.dtype, new_image.max()
# Out:
# ((512, 512, 3), dtype('float32'), 255.0)

# %%
mask = preds_view

# %%
new_image[mask[:,:]==0, :] = [128, 64, 128]
new_image[mask[:,:]==1, :] = [244, 35, 232]
new_image[mask[:,:]==2, :] = [70, 70, 70]
new_image[mask[:,:]==3, :] = [102, 102, 156]
new_image[mask[:,:]==4, :] = [190, 153, 153]
new_image[mask[:,:]==5, :] = [153, 153, 153]
new_image[mask[:,:]==6, :] = [250, 170, 30]
new_image[mask[:,:]==7, :] = [220, 220,  0]
new_image[mask[:,:]==8, :] = [107, 142, 35]
new_image[mask[:,:]==9, :] = [128, 64, 128]
new_image[mask[:,:]==10, :] = [152, 251, 152]
new_image[mask[:,:]==11, :] = [220, 20, 60]
new_image[mask[:,:]==12, :] = [255,  0,  0]
new_image[mask[:,:]==13, :] = [0, 0, 142]
new_image[mask[:,:]==14, :] = [0, 0, 70]
new_image[mask[:,:]==15, :] = [0, 60, 100]
new_image[mask[:,:]==16, :] = [0, 80, 100]
new_image[mask[:,:]==17, :] = [0, 0, 230]
new_image[mask[:,:]==18, :] = [119, 11, 32]
new_image[mask[:,:]==19, :] = [128, 64, 128]

# %%
plt.imshow(new_image)

# %%
new_image2 = Image.blend(Image.fromarray(new_image, mode='RGB').convert('RGBA'),
                        Image.fromarray(new_image, mode='RGB').convert('RGBA'),
                        alpha=0.5)

# %%
plt.imshow(new_image)

# %%
Image.fromarray(new_image, mode='RGB')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-591b12ad0f79> in <module>()
# ----> 1 Image.fromarray(new_image, mode='RGB')
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2443             obj = obj.tostring()
#    2444
# -> 2445     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2446
#    2447
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2396             return im
#    2397
# -> 2398     return frombytes(mode, size, data, decoder_name, args)
#    2399
#    2400
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2329
#    2330     im = new(mode, size)
# -> 2331     im.frombytes(data, decoder_name, args)
#    2332     return im
#    2333
#
# ~/anaconda3/envs/tf1.4_gpu/lib/python3.6/site-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     781         d = _getdecoder(self.mode, decoder_name, args)
#     782         d.setimage(self.im)
# --> 783         s = d.decode(data)
#     784
#     785         if s[0] >= 0:
#
# TypeError: a bytes-like object is required, not 'Image'

# %%
new_image = Image.blend(Image.fromarray(test_img, mode='RGB').convert('RGBA'),
                        Image.fromarray(new_image, mode='RGB').convert('RGBA'),
                        alpha=0.5)

# %%
(test_img/255.0).dtype, (test_img/255.0).max(), (test_img/255.0).min()
# Out:
# (dtype('float32'), 1.0, 0.0)

# %%
# visualize_prediction for cityscape data
def visualize_prediction(original_image, mask):
    
    #original_image = np.squeeze(original_image).astype(np.uint8)
    new_image = np.copy(original_image)
    #prediction = np.squeeze(prediction)
    #mask = np.argmax(prediction, axis=2)

    new_image[mask[:,:]==0, :] = [128, 64, 128]
    new_image[mask[:,:]==1, :] = [244, 35, 232]
    new_image[mask[:,:]==2, :] = [70, 70, 70]
    new_image[mask[:,:]==3, :] = [102, 102, 156]
    new_image[mask[:,:]==4, :] = [190, 153, 153]
    new_image[mask[:,:]==5, :] = [153, 153, 153]
    new_image[mask[:,:]==6, :] = [250, 170, 30]
    new_image[mask[:,:]==7, :] = [220, 220,  0]
    new_image[mask[:,:]==8, :] = [107, 142, 35]
    new_image[mask[:,:]==9, :] = [128, 64, 128]
    new_image[mask[:,:]==10, :] = [152, 251, 152]
    new_image[mask[:,:]==11, :] = [220, 20, 60]
    new_image[mask[:,:]==12, :] = [255,  0,  0]
    new_image[mask[:,:]==13, :] = [0, 0, 142]
    new_image[mask[:,:]==14, :] = [0, 0, 70]
    new_image[mask[:,:]==15, :] = [0, 60, 100]
    new_image[mask[:,:]==16, :] = [0, 80, 100]
    new_image[mask[:,:]==17, :] = [0, 0, 230]
    new_image[mask[:,:]==18, :] = [119, 11, 32]
    new_image[mask[:,:]==19, :] = [128, 64, 128]
    
    new_image = Image.blend(Image.fromarray(original_image, mode='RGB').convert('RGBA'),
                            Image.fromarray(new_image, mode='RGB').convert('RGBA'),
                            alpha=0.5)
    
    plt.imshow(new_image)
    #plt.imshow(new_image, interpolation='nearest')
    plt.show()

# %%
test_img_ori=mpimg.imread("/data/cityscapes_dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png")
plt.imshow(test_img_ori)

# %%
test_img.dtype, test_img.max(), test_img.min()
# Out:
# (dtype('float32'), 255.0, 0.0)
